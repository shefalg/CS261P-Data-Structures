# %%
import matplotlib
from matplotlib import pyplot as plt
x = [100,1000,10000,100000,1000000]
y1 = [0.021,0.02,0.013,0.011,0.021] #bst
y2 = [0.0138,0.0243,0.0556,0.0645,0.0789] #splay
y3 = [0.025,0.01,0.012,0.044,0.026]
y4 = [0.064,0.007,0.009,0.007,0.025]

#ax.plot(x, y1,'bo-')
#ax.set_yscale('log')
ax.set_xticks([100,1000,10000,100000,1000000])
#ax.set_yticks([0.004,0.062,0.167,0.265,2.314,11.749,47.898,183.135,755.168])
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.xlabel('Number of elements')
plt.ylabel('Insertion Time (milli seconds)')
plt.title('Insertion')
plt.plot(x,y1,c='r',label='BST')
plt.plot(x,y2,c='b',label='Splay tree')
plt.plot(x,y3,c='g',label='AVL')
plt.plot(x,y4,c='y',label='Treap')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
x = [100,1000,10000,100000,1000000]
y1 = [0.019,0.025,0.034,0.047,0.047] #bst
y2 = [0.0197,0.0243,0.0338,0.0445,0.0589] #splay
y3 = [0.02,0.066,0.032,0.061,0.054] #avl
y4 = [0.064,0.0346,0.028,.0461,0.0861] #treap

#ax.plot(x, y1,'bo-')
#ax.set_yscale('log')
ax.set_xticks([100,1000,10000,100000,1000000])
#ax.set_yticks([0.004,0.062,0.167,0.265,2.314,11.749,47.898,183.135,755.168])
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.xlabel('Number of elements')
plt.ylabel('Searcg Time (milli seconds)')
plt.title('Search')
plt.plot(x,y1,c='r',label='BST')
plt.plot(x,y2,c='b',label='Splay tree')
plt.plot(x,y3,c='g',label='AVL')
plt.plot(x,y4,c='y',label='Treap')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
x = [100,1000,10000,100000,1000000]
y1 = [0.029,0.014,0.018,0.014,0.019] #bst
y2 = [0.11,0.205,0.309,0.311,0.376] #splay
y3 = [0.031,0.042,0.039,0.055,0.057] #avl
y4 = [0.024,0.024,0.027,0.02,0.03] #treap

#ax.plot(x, y1,'bo-')
#ax.set_yscale('log')
ax.set_xticks([100,1000,10000,100000,1000000])
#ax.set_yticks([0.004,0.062,0.167,0.265,2.314,11.749,47.898,183.135,755.168])
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.xlabel('Deletion Time (milli seconds)')
plt.title('Deletion')
plt.plot(x,y1,c='r',label='BST')
plt.plot(x,y2,c='b',label='Splay tree')
plt.plot(x,y3,c='g',label='AVL')
plt.plot(x,y4,c='y',label='Treap')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
